# %%
from pydub import AudioSegment
import math
import time
import pandas as pd
import numpy as np

audio = AudioSegment.from_file("VoiceAudioTest.wav")
time_split = 0.25 * 1000
length = len(audio)
volume_list=[]

# %%
for i in range(math.floor(length/time_split)):
    start = time_split * i
    end = time_split * (i+1)
    if end >= length:
        end = length
    loudness_audio = audio[start:end].dBFS
    print("-"*(math.ceil(loudness_audio))+str(start)+"-"+str(end)+": "+str(loudness_audio)+" dBFS")
    volume_list.append(loudness_audio)
    #time.sleep(1)
# Out:
# 0.0-250.0: -64.73392668013777 dBFS
# 250.0-500.0: -63.074441978842486 dBFS
# 500.0-750.0: -63.074441978842486 dBFS
# 750.0-1000.0: -63.86461280451597 dBFS
# 1000.0-1250.0: -63.46054508275023 dBFS
# 1250.0-1500.0: -46.012121738240396 dBFS
# 1500.0-1750.0: -28.198795003794878 dBFS
# 1750.0-2000.0: -31.11863115973439 dBFS
# 2000.0-2250.0: -35.100549030730114 dBFS
# 2250.0-2500.0: -33.04254149678523 dBFS
# 2500.0-2750.0: -32.796199959110986 dBFS
# 2750.0-3000.0: -49.96833191321875 dBFS
# 3000.0-3250.0: -63.86461280451597 dBFS
# 3250.0-3500.0: -63.46054508275023 dBFS
# 3500.0-3750.0: -61.68172341601461 dBFS
# 3750.0-4000.0: -31.147281728772654 dBFS
# 4000.0-4250.0: -27.85812821781927 dBFS
# 4250.0-4500.0: -37.51926891382263 dBFS
# 4500.0-4750.0: -31.710407497502597 dBFS
# 4750.0-5000.0: -51.22414851040786 dBFS
# 5000.0-5250.0: -62.009531739778 dBFS
# 5250.0-5500.0: -62.009531739778 dBFS
# 5500.0-5750.0: -62.3501985257536 dBFS
# 5750.0-6000.0: -28.349977279311354 dBFS
# 6000.0-6250.0: -29.13288896567622 dBFS
# 6250.0-6500.0: -33.21073825303724 dBFS
# 6500.0-6750.0: -40.34278762340235 dBFS
# 6750.0-7000.0: -62.3501985257536 dBFS
# 7000.0-7250.0: -62.3501985257536 dBFS
# 7250.0-7500.0: -35.872786394943425 dBFS
# 7500.0-7750.0: -33.0783104820136 dBFS
# 7750.0-8000.0: -23.269209590481715 dBFS
# 8000.0-8250.0: -30.231175374456143 dBFS
# 8250.0-8500.0: -33.32061042325637 dBFS
# 8500.0-8750.0: -47.44870269411245 dBFS
# 8750.0-9000.0: -62.704773864962235 dBFS
# 9000.0-9250.0: -63.46054508275023 dBFS
# 9250.0-9500.0: -29.762006543699226 dBFS
# 9500.0-9750.0: -30.90206117459249 dBFS
# 9750.0-10000.0: -40.88316447801559 dBFS
# 10000.0-10250.0: -35.72570290533895 dBFS
# 10250.0-10500.0: -55.0404388279356 dBFS
# 10500.0-10750.0: -28.510896470406397 dBFS
# 10750.0-11000.0: -31.730844894315304 dBFS
# 11000.0-11250.0: -39.15885466108119 dBFS
# 11250.0-11500.0: -38.992042325724 dBFS
# 11500.0-11750.0: -37.20623000296671 dBFS
# 11750.0-12000.0: -31.74108165406008 dBFS
# 12000.0-12250.0: -34.03737892783052 dBFS
# 12250.0-12500.0: -36.505077098624085 dBFS
# 12500.0-12750.0: -59.9387199016366 dBFS
# 12750.0-13000.0: -36.17464305245918 dBFS
# 13000.0-13250.0: -31.23380486452978 dBFS
# 13250.0-13500.0: -50.754526593417395 dBFS
# 13500.0-13750.0: -63.46054508275023 dBFS
# 13750.0-14000.0: -63.46054508275023 dBFS
# 14000.0-14250.0: -62.704773864962235 dBFS
# 14250.0-14500.0: -60.76657360480111 dBFS
# 14500.0-14750.0: -28.747115691066142 dBFS
# 14750.0-15000.0: -28.603187134593053 dBFS
# 15000.0-15250.0: -26.96856278338923 dBFS
# 15250.0-15500.0: -32.715614586553286 dBFS
# 15500.0-15750.0: -37.439945169470604 dBFS
# 15750.0-16000.0: -33.89183891040035 dBFS
# 16000.0-16250.0: -25.81315956934073 dBFS
# 16250.0-16500.0: -32.97144241244438 dBFS
# 16500.0-16750.0: -48.87135855307185 dBFS
# 16750.0-17000.0: -63.074441978842486 dBFS
# 17000.0-17250.0: -63.86461280451597 dBFS
# 17250.0-17500.0: -35.629012968426615 dBFS
# 17500.0-17750.0: -28.164799306236986 dBFS
# 17750.0-18000.0: -29.004876138108116 dBFS
# 18000.0-18250.0: -39.52747672333882 dBFS
# 18250.0-18500.0: -61.36583807234997 dBFS
# 18500.0-18750.0: -63.074441978842486 dBFS
# 18750.0-19000.0: -63.074441978842486 dBFS
# 19000.0-19250.0: -62.704773864962235 dBFS
# 19250.0-19500.0: -63.46054508275023 dBFS
# 19500.0-19750.0: -55.98893182649837 dBFS
# 19750.0-20000.0: -27.111641757343023 dBFS
# 20000.0-20250.0: -28.610327200460034 dBFS
# 20250.0-20500.0: -30.827980643336808 dBFS
# 20500.0-20750.0: -29.410367776211153 dBFS
# 20750.0-21000.0: -43.61992367617574 dBFS
# 21000.0-21250.0: -36.243171136821125 dBFS
# 21250.0-21500.0: -37.844012891236346 dBFS
# 21500.0-21750.0: -41.12114894400974 dBFS
# 21750.0-22000.0: -34.877249081569246 dBFS
# 22000.0-22250.0: -30.457928342551646 dBFS
# 22250.0-22500.0: -32.88922242398285 dBFS
# 22500.0-22750.0: -31.83375948262035 dBFS
# 22750.0-23000.0: -38.13847802765047 dBFS
# 23000.0-23250.0: -45.802813064677096 dBFS
# 23250.0-23500.0: -63.46054508275023 dBFS
# 23500.0-23750.0: -63.46054508275023 dBFS
# 23750.0-24000.0: -62.3501985257536 dBFS
# 24000.0-24250.0: -43.22682991624633 dBFS
# 24250.0-24500.0: -27.657401745999618 dBFS
# 24500.0-24750.0: -39.03937699130614 dBFS
# 24750.0-25000.0: -27.300010509976744 dBFS
# 25000.0-25250.0: -31.05214507516951 dBFS
# 25250.0-25500.0: -32.50057832317607 dBFS
# 25500.0-25750.0: -31.79244720669951 dBFS
# 25750.0-26000.0: -27.92388091363562 dBFS
# 26000.0-26250.0: -33.174420891536705 dBFS
# 26250.0-26500.0: -34.53149638368602 dBFS
# 26500.0-26750.0: -39.1108661984721 dBFS
# 26750.0-27000.0: -38.465463551277026 dBFS
# 27000.0-27250.0: -47.574587356066225 dBFS
# 27250.0-27500.0: -37.70044119869388 dBFS
# 27500.0-27750.0: -53.40703789890922 dBFS
# 27750.0-28000.0: -62.3501985257536 dBFS
# 28000.0-28250.0: -62.704773864962235 dBFS
# 28250.0-28500.0: -63.074441978842486 dBFS
# 28500.0-28750.0: -62.704773864962235 dBFS
# 28750.0-29000.0: -30.052254205090914 dBFS
# 29000.0-29250.0: -30.17967785420972 dBFS
# 29250.0-29500.0: -32.48940675940057 dBFS
# 29500.0-29750.0: -27.251006771319407 dBFS
# 29750.0-30000.0: -38.69049918568197 dBFS
# 30000.0-30250.0: -62.704773864962235 dBFS
# 30250.0-30500.0: -36.08973631928884 dBFS
# 30500.0-30750.0: -30.23978805700423 dBFS
# 30750.0-31000.0: -32.44486363799739 dBFS
# 31000.0-31250.0: -27.87780181544434 dBFS
# 31250.0-31500.0: -32.80777343136036 dBFS
# 31500.0-31750.0: -49.96833191321875 dBFS
# 31750.0-32000.0: -62.009531739778 dBFS
# 32000.0-32250.0: -62.3501985257536 dBFS
# 32250.0-32500.0: -31.57872384961649 dBFS
# 32500.0-32750.0: -34.33598579028897 dBFS
# 32750.0-33000.0: -38.289540785459394 dBFS
# 33000.0-33250.0: -28.539189295546432 dBFS
# 33250.0-33500.0: -30.13699526395601 dBFS
# 33500.0-33750.0: -34.616652846536844 dBFS
# 33750.0-34000.0: -58.94496421785445 dBFS
# 34000.0-34250.0: -62.704773864962235 dBFS
# 34250.0-34500.0: -62.704773864962235 dBFS
# 34500.0-34750.0: -52.03272165152002 dBFS
# 34750.0-35000.0: -30.708931267519425 dBFS
# 35000.0-35250.0: -55.98893182649837 dBFS
# 35250.0-35500.0: -28.89346944232566 dBFS
# 35500.0-35750.0: -31.927436851672873 dBFS
# 35750.0-36000.0: -35.88928381611958 dBFS
# 36000.0-36250.0: -39.502409203376885 dBFS
# 36250.0-36500.0: -28.878722597292573 dBFS
# 36500.0-36750.0: -39.730664693641266 dBFS
# 36750.0-37000.0: -38.48770655866437 dBFS
# 37000.0-37250.0: -31.60893567012126 dBFS
# 37250.0-37500.0: -36.140580696500095 dBFS
# 37500.0-37750.0: -31.937908088188884 dBFS
# 37750.0-38000.0: -39.3289334586786 dBFS
# 38000.0-38250.0: -32.16077148370263 dBFS
# 38250.0-38500.0: -38.66773144096018 dBFS
# 38500.0-38750.0: -34.280924498847256 dBFS
# 38750.0-39000.0: -30.967404016304414 dBFS
# 39000.0-39250.0: -41.2426318982536 dBFS
# 39250.0-39500.0: -55.66112350273499 dBFS
# 39500.0-39750.0: -63.074441978842486 dBFS
# 39750.0-40000.0: -35.82348130717857 dBFS
# 40000.0-40250.0: -35.581068653661504 dBFS
# 40250.0-40500.0: -40.20599913279624 dBFS
# 40500.0-40750.0: -33.918119988356985 dBFS
# 40750.0-41000.0: -40.97164629211217 dBFS
# 41000.0-41250.0: -46.5585842824651 dBFS
# 41250.0-41500.0: -41.459403317905384 dBFS
# 41500.0-41750.0: -33.39463833986118 dBFS
# 41750.0-42000.0: -33.41945518428073 dBFS
# 42000.0-42250.0: -44.28839878591474 dBFS
# 42250.0-42500.0: -62.3501985257536 dBFS
# 42500.0-42750.0: -31.64938226073039 dBFS
# 42750.0-43000.0: -34.559789208826054 dBFS
# 43000.0-43250.0: -34.489229197418034 dBFS
# 43250.0-43500.0: -34.559789208826054 dBFS
# 43500.0-43750.0: -43.539868827102254 dBFS
# 43750.0-44000.0: -41.522344822589105 dBFS
# 44000.0-44250.0: -35.93896492184887 dBFS
# 44250.0-44500.0: -34.83326979957049 dBFS
# 44500.0-44750.0: -43.86461280451597 dBFS
# 44750.0-45000.0: -51.128170852772485 dBFS
# 45000.0-45250.0: -59.42763781218885 dBFS
# 45250.0-45500.0: -63.074441978842486 dBFS
# 45500.0-45750.0: -63.86461280451597 dBFS
# 45750.0-46000.0: -62.3501985257536 dBFS
# 46000.0-46250.0: -35.741923058769785 dBFS
# 46250.0-46500.0: -30.95803917481711 dBFS
# 46500.0-46750.0: -36.0224035042897 dBFS
# 46750.0-47000.0: -32.04332066398599 dBFS
# 47000.0-47250.0: -33.0783104820136 dBFS
# 47250.0-47500.0: -36.522821516721955 dBFS
# 47500.0-47750.0: -49.32463824579072 dBFS
# 47750.0-48000.0: -63.46054508275023 dBFS
# 48000.0-48250.0: -63.074441978842486 dBFS
# 48250.0-48500.0: -62.3501985257536 dBFS
# 48500.0-48750.0: -63.86461280451597 dBFS
# 48750.0-49000.0: -33.944480826915246 dBFS
# 49000.0-49250.0: -32.715614586553286 dBFS
# 49250.0-49500.0: -39.304431638092474 dBFS
# 49500.0-49750.0: -39.67942035834925 dBFS
# 49750.0-50000.0: -62.3501985257536 dBFS
# 50000.0-50250.0: -62.3501985257536 dBFS
# 50250.0-50500.0: -40.12494825257229 dBFS
# 50500.0-50750.0: -32.085846524394825 dBFS
# 50750.0-51000.0: -36.55841947490166 dBFS
# 51000.0-51250.0: -39.47741382026274 dBFS
# 51250.0-51500.0: -50.05225420509091 dBFS
# 51500.0-51750.0: -64.28839878591474 dBFS
# 51750.0-52000.0: -62.3501985257536 dBFS
# 52000.0-52250.0: -63.074441978842486 dBFS
# 52250.0-52500.0: -63.46054508275023 dBFS
# 52500.0-52750.0: -63.46054508275023 dBFS
# 52750.0-53000.0: -40.53798436918547 dBFS
# 53000.0-53250.0: -32.85422214974098 dBFS
# 53250.0-53500.0: -35.517551810192515 dBFS
# 53500.0-53750.0: -33.6205846255637 dBFS
# 53750.0-54000.0: -33.456813906983115 dBFS
# 54000.0-54250.0: -31.56867654989807 dBFS
# 54250.0-54500.0: -33.18650981434835 dBFS
# 54500.0-54750.0: -53.918119988356985 dBFS
# 54750.0-55000.0: -63.074441978842486 dBFS
# 55000.0-55250.0: -62.704773864962235 dBFS
# 55250.0-55500.0: -63.86461280451597 dBFS
# 55500.0-55750.0: -47.20227794989312 dBFS
# 55750.0-56000.0: -36.522821516721955 dBFS
# 56000.0-56250.0: -35.37631472044278 dBFS
# 56250.0-56500.0: -36.20883951252764 dBFS
# 56500.0-56750.0: -42.81403177899228 dBFS
# 56750.0-57000.0: -59.9387199016366 dBFS
# 57000.0-57250.0: -63.46054508275023 dBFS
# 57250.0-57500.0: -62.3501985257536 dBFS
# 57500.0-57750.0: -65.20354859712823 dBFS
# 57750.0-58000.0: -54.891958466351475 dBFS
# 58000.0-58250.0: -36.8301587265126 dBFS
# 58250.0-58500.0: -49.247429829525956 dBFS
# 58500.0-58750.0: -63.074441978842486 dBFS
# 58750.0-59000.0: -63.46054508275023 dBFS
# 59000.0-59250.0: -63.46054508275023 dBFS
# 59250.0-59500.0: -63.86461280451597 dBFS
# 59500.0-59750.0: -63.074441978842486 dBFS

# %%
df = pd.DataFrame({'col':volume_list})
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col     239 non-null    float64
# dtypes: float64(1)
# memory usage: 2.0 KB
# None

# %%
df['col']=(abs(df['col']))
df.index = np.abs(df.index)
df.plot.line(x=None, y=None)
print(audio.max_dBFS)
print(df.max())
print(df.min())
# Out:
# -11.210647624495182
# col    65.203549
# dtype: float64
# col    23.26921
# dtype: float64
